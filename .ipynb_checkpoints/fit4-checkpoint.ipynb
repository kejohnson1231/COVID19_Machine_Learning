# %%
import pandas as pd
import numpy as np
from rfpimp import *
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, mean_squared_error, roc_curve, precision_score, recall_score
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn import metrics


import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.forest module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
metadata_byday = pd.read_csv('data/metadata_byday.csv')

# %%
metadata_byday
# Out:
#        FIPS    STATE ST_ABBR      COUNTY  2020-03-22_confirmed  \
# 0      1001  ALABAMA      AL     Autauga                     0
# 1      1003  ALABAMA      AL     Baldwin                     2
# 2      1005  ALABAMA      AL     Barbour                     0
# 3      1007  ALABAMA      AL        Bibb                     0
# 4      1009  ALABAMA      AL      Blount                     0
# ...     ...      ...     ...         ...                   ...
# 3137  56037  WYOMING      WY  Sweetwater                     0
# 3138  56039  WYOMING      WY       Teton                     2
# 3139  56041  WYOMING      WY       Uinta                     0
# 3140  56043  WYOMING      WY    Washakie                     0
# 3141  56045  WYOMING      WY      Weston                     0
#
#       2020-03-22_deaths  2020-03-22_recovered  2020-03-22_active  \
# 0                     0                     0                  0
# 1                     0                     0                  0
# 2                     0                     0                  0
# 3                     0                     0                  0
# 4                     0                     0                  0
# ...                 ...                   ...                ...
# 3137                  0                     0                  0
# 3138                  0                     0                  0
# 3139                  0                     0                  0
# 3140                  0                     0                  0
# 3141                  0                     0                  0
#
#       2020-03-23_confirmed  2020-03-23_deaths  ...  2020-05-12_recovered  \
# 0                        0                  0  ...                   0.0
# 1                        3                  0  ...                   0.0
# 2                        0                  0  ...                   0.0
# 3                        0                  0  ...                   0.0
# 4                        0                  0  ...                   0.0
# ...                    ...                ...  ...                   ...
# 3137                     0                  0  ...                   0.0
# 3138                     2                  0  ...                   0.0
# 3139                     0                  0  ...                   0.0
# 3140                     0                  0  ...                   0.0
# 3141                     0                  0  ...                   0.0
#
#       2020-05-12_active  2020-05-13_confirmed  2020-05-13_deaths  \
# 0                  87.0                  93.0                4.0
# 1                 220.0                 231.0                7.0
# 2                  66.0                  69.0                1.0
# 3                  45.0                  46.0                1.0
# 4                  45.0                  45.0                0.0
# ...                 ...                   ...                ...
# 3137               20.0                  20.0                0.0
# 3138               98.0                  99.0                0.0
# 3139                9.0                   9.0                0.0
# 3140                8.0                   8.0                0.0
# 3141                0.0                   0.0                0.0
#
#       2020-05-13_recovered  2020-05-13_active  2020-05-14_confirmed  \
# 0                      0.0               89.0                 104.0
# 1                      0.0              224.0                 243.0
# 2                      0.0               68.0                  74.0
# 3                      0.0               45.0                  46.0
# 4                      0.0               45.0                  45.0
# ...                    ...                ...                   ...
# 3137                   0.0               20.0                  21.0
# 3138                   0.0               99.0                  99.0
# 3139                   0.0                9.0                   9.0
# 3140                   0.0                8.0                   8.0
# 3141                   0.0                0.0                   0.0
#
#       2020-05-14_deaths  2020-05-14_recovered  2020-05-14_active
# 0                   4.0                   0.0              100.0
# 1                   8.0                   0.0              235.0
# 2                   1.0                   0.0               73.0
# 3                   1.0                   0.0               45.0
# 4                   0.0                   0.0               45.0
# ...                 ...                   ...                ...
# 3137                0.0                   0.0               21.0
# 3138                0.0                   0.0               99.0
# 3139                0.0                   0.0                9.0
# 3140                0.0                   0.0                8.0
# 3141                0.0                   0.0                0.0
#
# [3142 rows x 220 columns]

# %%
state_orders = pd.read_csv('data/state_orders.csv')
state_orders
# Out:
#        FIPS    STATE date_announced date_effective   date_lift date_reopen  \
# 0      1001  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# 1      1003  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# 2      1005  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# 3      1007  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# 4      1009  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# ...     ...      ...            ...            ...         ...         ...
# 3137  56037  WYOMING     2020-07-04     2020-07-04  2020-07-04  2020-05-01
# 3138  56039  WYOMING     2020-07-04     2020-07-04  2020-07-04  2020-05-01
# 3139  56041  WYOMING     2020-07-04     2020-07-04  2020-07-04  2020-05-01
# 3140  56043  WYOMING     2020-07-04     2020-07-04  2020-07-04  2020-05-01
# 3141  56045  WYOMING     2020-07-04     2020-07-04  2020-07-04  2020-05-01
#
#       order_length  days_since_order  days_since_reopen  ann_to_eff  reopened  \
# 0               26                91                 65           1         1
# 1               26                91                 65           1         1
# 2               26                91                 65           1         1
# 3               26                91                 65           1         1
# 4               26                91                 65           1         1
# ...            ...               ...                ...         ...       ...
# 3137             0                 0                 64           0         1
# 3138             0                 0                 64           0         1
# 3139             0                 0                 64           0         1
# 3140             0                 0                 64           0         1
# 3141             0                 0                 64           0         1
#
#       days_since_lifted  lifted
# 0                    65       1
# 1                    65       1
# 2                    65       1
# 3                    65       1
# 4                    65       1
# ...                 ...     ...
# 3137                  0       1
# 3138                  0       1
# 3139                  0       1
# 3140                  0       1
# 3141                  0       1
#
# [3142 rows x 13 columns]

# %%
sociohealth = pd.read_csv('data/sociohealth.csv')
sociohealth
# Out:
#        FIPS  population_density  %_below_poverty_line  %_disabled  %_minority  \
# 0      1001           92.859967                  15.4        19.3        25.0
# 1      1003          130.901947                  10.6        14.0        17.0
# 2      1005           29.132150                  28.9        22.2        53.9
# 3      1007           36.190214                  14.0        16.7        25.4
# 4      1009           89.395591                  14.4        14.2        12.9
# ...     ...                 ...                   ...         ...         ...
# 3137  56037            4.231045                  12.0        12.3        20.4
# 3138  56039            5.769301                   7.1         7.0        18.4
# 3139  56041            9.899987                  12.5        17.2        12.5
# 3140  56043            3.631169                  12.4        14.9        18.0
# 3141  56045            2.960796                  17.4        14.4         8.9
#
#       %multi_unit_housing  %_overcrowded  %_no_vehicle  %_group_quarters  \
# 0                     3.8            1.4           5.6               1.0
# 1                    18.3            1.3           3.4               1.4
# 2                     1.3            3.4           9.2              11.2
# 3                     2.4            0.8           6.0               9.3
# 4                     0.9            1.6           4.2               0.9
# ...                   ...            ...           ...               ...
# 3137                  5.5            1.9           2.4               1.3
# 3138                  7.5            7.2           2.4               4.0
# 3139                  5.8            2.8           3.9               1.3
# 3140                  1.1            1.8           5.0               2.0
# 3141                  2.6            2.3           2.6               5.1
#
#       %_fair_poor_health  ...  segregation_index  population  %_female  \
# 0                     18  ...               24.0       55416      51.3
# 1                     18  ...               31.0      208563      51.5
# 2                     26  ...               22.0       25965      46.9
# 3                     20  ...               42.0       22643      46.4
# 4                     21  ...               24.0       57704      50.6
# ...                  ...  ...                ...         ...       ...
# 3137                  15  ...               29.0       44165      48.2
# 3138                  12  ...               27.0       23191      48.4
# 3139                  16  ...               16.0       20773      49.4
# 3140                  16  ...               28.0        8235      49.7
# 3141                  13  ...               33.0        7236      47.3
#
#       %_rural  pcp_rate  %_65andup  %_uninsured  %_limited_english  \
# 0        42.0      74.0      14.65         8.05               0.80
# 1        42.3     117.0      19.60        11.10               0.65
# 2        67.8      69.0      18.00        12.10               1.55
# 3        68.4     128.0      15.85         9.95               0.35
# 4        90.0      33.0      17.90        12.50               1.80
# ...       ...       ...        ...          ...                ...
# 3137     10.9      88.0      10.60        12.00               1.85
# 3138     46.4     229.0      13.55        12.50               3.95
# 3139     43.1     106.0      12.35        12.10               1.00
# 3140     36.0      97.0      20.80        16.20               0.50
# 3141     54.5     110.0      18.80        13.65               1.00
#
#       %_clinton_votes_2016  %_trump_votes_2016
# 0                 0.239569            0.734358
# 1                 0.195653            0.773515
# 2                 0.466603            0.522714
# 3                 0.214220            0.769662
# 4                 0.084699            0.898519
# ...                    ...                 ...
# 3137              0.194046            0.729428
# 3138              0.600608            0.321945
# 3139              0.149261            0.764187
# 3140              0.143203            0.783580
# 3141              0.088182            0.869226
#
# [3142 rows x 31 columns]

# %%
races = pd.read_csv('data/race_df.csv')
races
# Out:
#        FIPS  %_african_american  %_natamer_alaskan  %_asian  %_hawaii_pacisl  \
# 0      1001                19.0                0.5      1.1              0.1
# 1      1003                 9.0                0.8      1.1              0.1
# 2      1005                47.5                0.6      0.5              0.2
# 3      1007                21.6                0.4      0.2              0.1
# 4      1009                 1.4                0.6      0.3              0.1
# ...     ...                 ...                ...      ...              ...
# 3137  56037                 1.1                1.5      0.8              0.2
# 3138  56039                 0.6                0.9      1.2              0.1
# 3139  56041                 0.7                1.3      0.6              0.2
# 3140  56043                 0.5                1.7      0.8              0.1
# 3141  56045                 0.6                1.5      0.6              0.0
#
#       %_hisp  %_nonhisp_white
# 0        2.7             75.0
# 1        4.4             83.2
# 2        4.2             46.5
# 3        2.5             74.4
# 4        9.1             87.5
# ...      ...              ...
# 3137    16.1             79.6
# 3138    15.1             81.5
# 3139     9.0             87.5
# 3140    13.9             82.6
# 3141     4.0             91.9
#
# [3142 rows x 7 columns]

# %%
sociohealth2 = pd.merge(sociohealth, races, how = 'left', on = 'FIPS')
sociohealth2
# Out:
#        FIPS  population_density  %_below_poverty_line  %_disabled  %_minority  \
# 0      1001           92.859967                  15.4        19.3        25.0
# 1      1003          130.901947                  10.6        14.0        17.0
# 2      1005           29.132150                  28.9        22.2        53.9
# 3      1007           36.190214                  14.0        16.7        25.4
# 4      1009           89.395591                  14.4        14.2        12.9
# ...     ...                 ...                   ...         ...         ...
# 3137  56037            4.231045                  12.0        12.3        20.4
# 3138  56039            5.769301                   7.1         7.0        18.4
# 3139  56041            9.899987                  12.5        17.2        12.5
# 3140  56043            3.631169                  12.4        14.9        18.0
# 3141  56045            2.960796                  17.4        14.4         8.9
#
#       %multi_unit_housing  %_overcrowded  %_no_vehicle  %_group_quarters  \
# 0                     3.8            1.4           5.6               1.0
# 1                    18.3            1.3           3.4               1.4
# 2                     1.3            3.4           9.2              11.2
# 3                     2.4            0.8           6.0               9.3
# 4                     0.9            1.6           4.2               0.9
# ...                   ...            ...           ...               ...
# 3137                  5.5            1.9           2.4               1.3
# 3138                  7.5            7.2           2.4               4.0
# 3139                  5.8            2.8           3.9               1.3
# 3140                  1.1            1.8           5.0               2.0
# 3141                  2.6            2.3           2.6               5.1
#
#       %_fair_poor_health  ...  %_uninsured  %_limited_english  \
# 0                     18  ...         8.05               0.80
# 1                     18  ...        11.10               0.65
# 2                     26  ...        12.10               1.55
# 3                     20  ...         9.95               0.35
# 4                     21  ...        12.50               1.80
# ...                  ...  ...          ...                ...
# 3137                  15  ...        12.00               1.85
# 3138                  12  ...        12.50               3.95
# 3139                  16  ...        12.10               1.00
# 3140                  16  ...        16.20               0.50
# 3141                  13  ...        13.65               1.00
#
#       %_clinton_votes_2016  %_trump_votes_2016  %_african_american  \
# 0                 0.239569            0.734358                19.0
# 1                 0.195653            0.773515                 9.0
# 2                 0.466603            0.522714                47.5
# 3                 0.214220            0.769662                21.6
# 4                 0.084699            0.898519                 1.4
# ...                    ...                 ...                 ...
# 3137              0.194046            0.729428                 1.1
# 3138              0.600608            0.321945                 0.6
# 3139              0.149261            0.764187                 0.7
# 3140              0.143203            0.783580                 0.5
# 3141              0.088182            0.869226                 0.6
#
#       %_natamer_alaskan  %_asian  %_hawaii_pacisl  %_hisp  %_nonhisp_white
# 0                   0.5      1.1              0.1     2.7             75.0
# 1                   0.8      1.1              0.1     4.4             83.2
# 2                   0.6      0.5              0.2     4.2             46.5
# 3                   0.4      0.2              0.1     2.5             74.4
# 4                   0.6      0.3              0.1     9.1             87.5
# ...                 ...      ...              ...     ...              ...
# 3137                1.5      0.8              0.2    16.1             79.6
# 3138                0.9      1.2              0.1    15.1             81.5
# 3139                1.3      0.6              0.2     9.0             87.5
# 3140                1.7      0.8              0.1    13.9             82.6
# 3141                1.5      0.6              0.0     4.0             91.9
#
# [3142 rows x 37 columns]

# %%
sociohealth2.to_csv('data/sociohealth2.csv', index = False)

# %%
X = state_orders[['order_length','days_since_order', 'days_since_reopen', 'ann_to_eff']]

# %%
X = state_orders[['order_length','days_since_order', 'days_since_reopen']]

# %%
X = pd.merge(state_orders, sociohealth, how = 'left', on = 'FIPS')

# %%
X = pd.merge(state_orders, sociohealth2, how = 'left', on = 'FIPS')

# %%
X
# Out:
#        FIPS    STATE date_announced date_effective   date_lift date_reopen  \
# 0      1001  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# 1      1003  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# 2      1005  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# 3      1007  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# 4      1009  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# ...     ...      ...            ...            ...         ...         ...
# 3137  56037  WYOMING     2020-07-04     2020-07-04  2020-07-04  2020-05-01
# 3138  56039  WYOMING     2020-07-04     2020-07-04  2020-07-04  2020-05-01
# 3139  56041  WYOMING     2020-07-04     2020-07-04  2020-07-04  2020-05-01
# 3140  56043  WYOMING     2020-07-04     2020-07-04  2020-07-04  2020-05-01
# 3141  56045  WYOMING     2020-07-04     2020-07-04  2020-07-04  2020-05-01
#
#       order_length  days_since_order  days_since_reopen  ann_to_eff  ...  \
# 0               26                91                 65           1  ...
# 1               26                91                 65           1  ...
# 2               26                91                 65           1  ...
# 3               26                91                 65           1  ...
# 4               26                91                 65           1  ...
# ...            ...               ...                ...         ...  ...
# 3137             0                 0                 64           0  ...
# 3138             0                 0                 64           0  ...
# 3139             0                 0                 64           0  ...
# 3140             0                 0                 64           0  ...
# 3141             0                 0                 64           0  ...
#
#       %_uninsured  %_limited_english  %_clinton_votes_2016  \
# 0            8.05               0.80              0.239569
# 1           11.10               0.65              0.195653
# 2           12.10               1.55              0.466603
# 3            9.95               0.35              0.214220
# 4           12.50               1.80              0.084699
# ...           ...                ...                   ...
# 3137        12.00               1.85              0.194046
# 3138        12.50               3.95              0.600608
# 3139        12.10               1.00              0.149261
# 3140        16.20               0.50              0.143203
# 3141        13.65               1.00              0.088182
#
#       %_trump_votes_2016  %_african_american  %_natamer_alaskan  %_asian  \
# 0               0.734358                19.0                0.5      1.1
# 1               0.773515                 9.0                0.8      1.1
# 2               0.522714                47.5                0.6      0.5
# 3               0.769662                21.6                0.4      0.2
# 4               0.898519                 1.4                0.6      0.3
# ...                  ...                 ...                ...      ...
# 3137            0.729428                 1.1                1.5      0.8
# 3138            0.321945                 0.6                0.9      1.2
# 3139            0.764187                 0.7                1.3      0.6
# 3140            0.783580                 0.5                1.7      0.8
# 3141            0.869226                 0.6                1.5      0.6
#
#       %_hawaii_pacisl  %_hisp  %_nonhisp_white
# 0                 0.1     2.7             75.0
# 1                 0.1     4.4             83.2
# 2                 0.2     4.2             46.5
# 3                 0.1     2.5             74.4
# 4                 0.1     9.1             87.5
# ...               ...     ...              ...
# 3137              0.2    16.1             79.6
# 3138              0.1    15.1             81.5
# 3139              0.2     9.0             87.5
# 3140              0.1    13.9             82.6
# 3141              0.0     4.0             91.9
#
# [3142 rows x 49 columns]

# %%
X.columns
# Out:
# Index(['FIPS', 'STATE', 'date_announced', 'date_effective', 'date_lift',
#        'date_reopen', 'order_length', 'days_since_order', 'days_since_reopen',
#        'ann_to_eff', 'reopened', 'days_since_lifted', 'lifted',
#        'population_density', '%_below_poverty_line', '%_disabled',
#        '%_minority', '%multi_unit_housing', '%_overcrowded', '%_no_vehicle',
#        '%_group_quarters', '%_fair_poor_health', '%_smokers', '%_obese',
#        '%_physically_inactive', 'preventable_hospitalization_rate_medicare',
#        'air_pollution', '%_unemployed', 'age_adjusted_mortality_rate',
#        '%_diabetes', '%_insufficent_sleep', 'health_costs', 'med_house_income',
#        'segregation_index', 'population', '%_female', '%_rural', 'pcp_rate',
#        '%_65andup', '%_uninsured', '%_limited_english', '%_clinton_votes_2016',
#        '%_trump_votes_2016', '%_african_american', '%_natamer_alaskan',
#        '%_asian', '%_hawaii_pacisl', '%_hisp', '%_nonhisp_white'],
#       dtype='object')

# %%
X.drop(columns = ['FIPS', 'STATE','date_announced','date_effective','date_lift','date_reopen'], inplace = True)

# %%
X.drop(columns = ['ann_to_eff', '%_diabetes', '%_unemployed'], inplace = True)

# %%
X.drop(columns = ['%_minority'], inplace = True)

# %%
X.drop(columns = ['%_disabled', 'pcp_rate', '%_group_quarters', ], inplace = True)

# %%
X.drop(columns = ['lifted', 'reopened'], inplace = True)

# %%
X
# Out:
#       order_length  days_since_order  days_since_reopen  days_since_lifted  \
# 0               26                91                 65                 65
# 1               26                91                 65                 65
# 2               26                91                 65                 65
# 3               26                91                 65                 65
# 4               26                91                 65                 65
# ...            ...               ...                ...                ...
# 3137             0                 0                 64                  0
# 3138             0                 0                 64                  0
# 3139             0                 0                 64                  0
# 3140             0                 0                 64                  0
# 3141             0                 0                 64                  0
#
#       population_density  %_below_poverty_line  %multi_unit_housing  \
# 0              92.859967                  15.4                  3.8
# 1             130.901947                  10.6                 18.3
# 2              29.132150                  28.9                  1.3
# 3              36.190214                  14.0                  2.4
# 4              89.395591                  14.4                  0.9
# ...                  ...                   ...                  ...
# 3137            4.231045                  12.0                  5.5
# 3138            5.769301                   7.1                  7.5
# 3139            9.899987                  12.5                  5.8
# 3140            3.631169                  12.4                  1.1
# 3141            2.960796                  17.4                  2.6
#
#       %_overcrowded  %_no_vehicle  %_fair_poor_health  ...  %_uninsured  \
# 0               1.4           5.6                  18  ...         8.05
# 1               1.3           3.4                  18  ...        11.10
# 2               3.4           9.2                  26  ...        12.10
# 3               0.8           6.0                  20  ...         9.95
# 4               1.6           4.2                  21  ...        12.50
# ...             ...           ...                 ...  ...          ...
# 3137            1.9           2.4                  15  ...        12.00
# 3138            7.2           2.4                  12  ...        12.50
# 3139            2.8           3.9                  16  ...        12.10
# 3140            1.8           5.0                  16  ...        16.20
# 3141            2.3           2.6                  13  ...        13.65
#
#       %_limited_english  %_clinton_votes_2016  %_trump_votes_2016  \
# 0                  0.80              0.239569            0.734358
# 1                  0.65              0.195653            0.773515
# 2                  1.55              0.466603            0.522714
# 3                  0.35              0.214220            0.769662
# 4                  1.80              0.084699            0.898519
# ...                 ...                   ...                 ...
# 3137               1.85              0.194046            0.729428
# 3138               3.95              0.600608            0.321945
# 3139               1.00              0.149261            0.764187
# 3140               0.50              0.143203            0.783580
# 3141               1.00              0.088182            0.869226
#
#       %_african_american  %_natamer_alaskan  %_asian  %_hawaii_pacisl  %_hisp  \
# 0                   19.0                0.5      1.1              0.1     2.7
# 1                    9.0                0.8      1.1              0.1     4.4
# 2                   47.5                0.6      0.5              0.2     4.2
# 3                   21.6                0.4      0.2              0.1     2.5
# 4                    1.4                0.6      0.3              0.1     9.1
# ...                  ...                ...      ...              ...     ...
# 3137                 1.1                1.5      0.8              0.2    16.1
# 3138                 0.6                0.9      1.2              0.1    15.1
# 3139                 0.7                1.3      0.6              0.2     9.0
# 3140                 0.5                1.7      0.8              0.1    13.9
# 3141                 0.6                1.5      0.6              0.0     4.0
#
#       %_nonhisp_white
# 0                75.0
# 1                83.2
# 2                46.5
# 3                74.4
# 4                87.5
# ...               ...
# 3137             79.6
# 3138             81.5
# 3139             87.5
# 3140             82.6
# 3141             91.9
#
# [3142 rows x 34 columns]

# %%
X.columns
# Out:
# Index(['order_length', 'days_since_order', 'days_since_reopen',
#        'days_since_lifted', 'population_density', '%_below_poverty_line',
#        '%multi_unit_housing', '%_overcrowded', '%_no_vehicle',
#        '%_fair_poor_health', '%_smokers', '%_obese', '%_physically_inactive',
#        'preventable_hospitalization_rate_medicare', 'air_pollution',
#        'age_adjusted_mortality_rate', '%_insufficent_sleep', 'health_costs',
#        'med_house_income', 'segregation_index', 'population', '%_female',
#        '%_rural', '%_65andup', '%_uninsured', '%_limited_english',
#        '%_clinton_votes_2016', '%_trump_votes_2016', '%_african_american',
#        '%_natamer_alaskan', '%_asian', '%_hawaii_pacisl', '%_hisp',
#        '%_nonhisp_white'],
#       dtype='object')

# %%
y = (metadata_byday.iloc[:,-1] > metadata_byday.iloc[:,-5]).astype(int)

# %%
y.value_counts()
# Out:
# 0    1761
# 1    1381
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
rfc = RandomForestClassifier(n_estimators = 175, max_features = 10, oob_score = True)
rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-f1871808e0f6> in <module>
#       1 rfc = RandomForestClassifier(n_estimators = 175, max_features = 10, oob_score = True)
# ----> 2 rfc.fit(X_train, y_train)
#       3
#       4 y_pred = rfc.predict(X_test)
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     293         """
#     294         # Validate or convert input data
# --> 295         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     296         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     297         if sample_weight is not None:
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     576         if force_all_finite:
#     577             _assert_all_finite(array,
# --> 578                                allow_nan=force_all_finite == 'allow-nan')
#     579
#     580     if ensure_min_samples > 0:
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      58                     msg_err.format
#      59                     (type_err,
# ---> 60                      msg_dtype if msg_dtype is not None else X.dtype)
#      61             )
#      62     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))

# %%
feature_scores = pd.Series(rfc.feature_importances_, index=X.columns)
feature_scores = feature_scores.sort_values()

ax = feature_scores.plot(kind='barh', figsize=(10,10))
ax.set_title('Average Gini Importance')
ax.set_xlabel('Average contribution of information gain')

# %%
imp = importances(rfc, X_test, y_test, n_samples=-1)
viz = plot_importances(imp)
viz.view()

# %%
#rf1 = rfc.fit(X_train1, y_train1)
confusion_matrix(y_test, rfc.predict(X_test))

# %%
precision_score(y_test, rfc.predict(X_test))

# %%
recall_score(y_test, rfc.predict(X_test))

# %%
estimator_list = [50, 75, 100, 125, 150, 175, 200]
score_list = []
for i in estimator_list:
    rfc1 = RandomForestClassifier(n_estimators=i, oob_score=True)
    rfc1.fit(X_train, y_train)
    score_list.append(rfc1.score(X_test, y_test))
estimator_scores = dict(zip(estimator_list, score_list))
estimator_scores

# %%
x = estimator_list
y = score_list
fig, ax = plt.subplots()
ax.plot(x,y)

# %%
max_features = []
score_list = []
for i in range(1, len(X.columns)):
    rfc2 = RandomForestClassifier(max_features=i, oob_score=True)
    rfc2.fit(X_train, y_train)
    score_list.append(rfc2.score(X_test, y_test))
    max_features.append(i)
feature_scores = dict(zip(max_features, score_list))
feature_scores

# %%
x = max_features
y = score_list
fig, ax = plt.subplots()
ax.plot(x,y)
