# %%
import pandas as pd
import numpy as np
from rfpimp import *
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, mean_squared_error, roc_curve, precision_score, recall_score
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
metadata_byday = pd.read_csv('data/metadata_byday.csv')
meta

# %%
metadata_byday
# Out:
#        FIPS    STATE ST_ABBR      COUNTY  2020-03-22_confirmed  \
# 0      1001  ALABAMA      AL     Autauga                     0
# 1      1003  ALABAMA      AL     Baldwin                     2
# 2      1005  ALABAMA      AL     Barbour                     0
# 3      1007  ALABAMA      AL        Bibb                     0
# 4      1009  ALABAMA      AL      Blount                     0
# ...     ...      ...     ...         ...                   ...
# 3137  56037  WYOMING      WY  Sweetwater                     0
# 3138  56039  WYOMING      WY       Teton                     2
# 3139  56041  WYOMING      WY       Uinta                     0
# 3140  56043  WYOMING      WY    Washakie                     0
# 3141  56045  WYOMING      WY      Weston                     0
#
#       2020-03-22_deaths  2020-03-22_recovered  2020-03-22_active  \
# 0                     0                     0                  0
# 1                     0                     0                  0
# 2                     0                     0                  0
# 3                     0                     0                  0
# 4                     0                     0                  0
# ...                 ...                   ...                ...
# 3137                  0                     0                  0
# 3138                  0                     0                  0
# 3139                  0                     0                  0
# 3140                  0                     0                  0
# 3141                  0                     0                  0
#
#       2020-03-23_confirmed  2020-03-23_deaths  ...  2020-05-11_recovered  \
# 0                        0                  0  ...                   0.0
# 1                        3                  0  ...                   0.0
# 2                        0                  0  ...                   0.0
# 3                        0                  0  ...                   0.0
# 4                        0                  0  ...                   0.0
# ...                    ...                ...  ...                   ...
# 3137                     0                  0  ...                   0.0
# 3138                     2                  0  ...                   0.0
# 3139                     0                  0  ...                   0.0
# 3140                     0                  0  ...                   0.0
# 3141                     0                  0  ...                   0.0
#
#       2020-05-11_active  2020-05-12_confirmed  2020-05-12_deaths  \
# 0                  80.0                  91.0                4.0
# 1                 218.0                 227.0                7.0
# 2                  60.0                  67.0                1.0
# 3                  45.0                  46.0                1.0
# 4                  45.0                  45.0                0.0
# ...                 ...                   ...                ...
# 3137               20.0                  20.0                0.0
# 3138               98.0                  98.0                0.0
# 3139                9.0                   9.0                0.0
# 3140                8.0                   8.0                0.0
# 3141                0.0                   0.0                0.0
#
#       2020-05-12_recovered  2020-05-12_active  2020-05-13_confirmed  \
# 0                      0.0               87.0                  93.0
# 1                      0.0              220.0                 231.0
# 2                      0.0               66.0                  69.0
# 3                      0.0               45.0                  46.0
# 4                      0.0               45.0                  45.0
# ...                    ...                ...                   ...
# 3137                   0.0               20.0                  20.0
# 3138                   0.0               98.0                  99.0
# 3139                   0.0                9.0                   9.0
# 3140                   0.0                8.0                   8.0
# 3141                   0.0                0.0                   0.0
#
#       2020-05-13_deaths  2020-05-13_recovered  2020-05-13_active
# 0                   4.0                   0.0               89.0
# 1                   7.0                   0.0              224.0
# 2                   1.0                   0.0               68.0
# 3                   1.0                   0.0               45.0
# 4                   0.0                   0.0               45.0
# ...                 ...                   ...                ...
# 3137                0.0                   0.0               20.0
# 3138                0.0                   0.0               99.0
# 3139                0.0                   0.0                9.0
# 3140                0.0                   0.0                8.0
# 3141                0.0                   0.0                0.0
#
# [3142 rows x 216 columns]

# %%
state_orders = pd.read_csv('data/state_orders.csv')
state_orders
# Out:
#        FIPS    STATE date_announced date_effective   date_lift date_reopen  \
# 0      1001  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# 1      1003  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# 2      1005  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# 3      1007  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# 4      1009  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# ...     ...      ...            ...            ...         ...         ...
# 3137  56037  WYOMING     2020-05-14     2020-05-14  2020-05-14  2020-05-01
# 3138  56039  WYOMING     2020-05-14     2020-05-14  2020-05-14  2020-05-01
# 3139  56041  WYOMING     2020-05-14     2020-05-14  2020-05-14  2020-05-01
# 3140  56043  WYOMING     2020-05-14     2020-05-14  2020-05-14  2020-05-01
# 3141  56045  WYOMING     2020-05-14     2020-05-14  2020-05-14  2020-05-01
#
#       order_length  days_since_order  days_since_reopen  ann_to_eff  reopened  \
# 0               26                40                 14           1         1
# 1               26                40                 14           1         1
# 2               26                40                 14           1         1
# 3               26                40                 14           1         1
# 4               26                40                 14           1         1
# ...            ...               ...                ...         ...       ...
# 3137             0                 0                 13           0         1
# 3138             0                 0                 13           0         1
# 3139             0                 0                 13           0         1
# 3140             0                 0                 13           0         1
# 3141             0                 0                 13           0         1
#
#       days_since_lifted  lifted
# 0                    14       1
# 1                    14       1
# 2                    14       1
# 3                    14       1
# 4                    14       1
# ...                 ...     ...
# 3137                  0       1
# 3138                  0       1
# 3139                  0       1
# 3140                  0       1
# 3141                  0       1
#
# [3142 rows x 13 columns]

# %%
sociohealth = pd.read_csv('data/sociohealth.csv')
sociohealth
# Out:
#        FIPS    Pop_Dens  perc_below_pov  perc_disabled  perc_minority  \
# 0      1001   92.859967            15.4           19.3           25.0
# 1      1003  130.901947            10.6           14.0           17.0
# 2      1005   29.132150            28.9           22.2           53.9
# 3      1007   36.190214            14.0           16.7           25.4
# 4      1009   89.395591            14.4           14.2           12.9
# ...     ...         ...             ...            ...            ...
# 3137  56037    4.231045            12.0           12.3           20.4
# 3138  56039    5.769301             7.1            7.0           18.4
# 3139  56041    9.899987            12.5           17.2           12.5
# 3140  56043    3.631169            12.4           14.9           18.0
# 3141  56045    2.960796            17.4           14.4            8.9
#
#       percent_multiunit_housing  perc_overcrowded  perc_no_vehicle  \
# 0                           3.8               1.4              5.6
# 1                          18.3               1.3              3.4
# 2                           1.3               3.4              9.2
# 3                           2.4               0.8              6.0
# 4                           0.9               1.6              4.2
# ...                         ...               ...              ...
# 3137                        5.5               1.9              2.4
# 3138                        7.5               7.2              2.4
# 3139                        5.8               2.8              3.9
# 3140                        1.1               1.8              5.0
# 3141                        2.6               2.3              2.6
#
#       perc_group_quarters  perc_fair_poor_health  ...  Population  perc_fem  \
# 0                     1.0                     18  ...       55416      51.3
# 1                     1.4                     18  ...      208563      51.5
# 2                    11.2                     26  ...       25965      46.9
# 3                     9.3                     20  ...       22643      46.4
# 4                     0.9                     21  ...       57704      50.6
# ...                   ...                    ...  ...         ...       ...
# 3137                  1.3                     15  ...       44165      48.2
# 3138                  4.0                     12  ...       23191      48.4
# 3139                  1.3                     16  ...       20773      49.4
# 3140                  2.0                     16  ...        8235      49.7
# 3141                  5.1                     13  ...        7236      47.3
#
#       perc_rural  pcp_rate_100k  65_older  17_younger  uninsured  lim_eng  \
# 0           42.0           74.0     14.65       24.30       8.05     0.80
# 1           42.3          117.0     19.60       21.80      11.10     0.65
# 2           67.8           69.0     18.00       21.10      12.10     1.55
# 3           68.4          128.0     15.85       20.75       9.95     0.35
# 4           90.0           33.0     17.90       23.30      12.50     1.80
# ...          ...            ...       ...         ...        ...      ...
# 3137        10.9           88.0     10.60       26.85      12.00     1.85
# 3138        46.4          229.0     13.55       19.00      12.50     3.95
# 3139        43.1          106.0     12.35       29.45      12.10     1.00
# 3140        36.0           97.0     20.80       23.90      16.20     0.50
# 3141        54.5          110.0     18.80       21.30      13.65     1.00
#
#        per_dem   per_gop
# 0     0.239569  0.734358
# 1     0.195653  0.773515
# 2     0.466603  0.522714
# 3     0.214220  0.769662
# 4     0.084699  0.898519
# ...        ...       ...
# 3137  0.194046  0.729428
# 3138  0.600608  0.321945
# 3139  0.149261  0.764187
# 3140  0.143203  0.783580
# 3141  0.088182  0.869226
#
# [3142 rows x 32 columns]

# %%
races = pd.read_csv('data/race_df.csv')
races
# Out:
#        FIPS  perc_afr_am  perc_nat_am_as  perc_asian  perc_nh_opi  perc_hisp  \
# 0      1001         19.0             0.5         1.1          0.1        2.7
# 1      1003          9.0             0.8         1.1          0.1        4.4
# 2      1005         47.5             0.6         0.5          0.2        4.2
# 3      1007         21.6             0.4         0.2          0.1        2.5
# 4      1009          1.4             0.6         0.3          0.1        9.1
# ...     ...          ...             ...         ...          ...        ...
# 3137  56037          1.1             1.5         0.8          0.2       16.1
# 3138  56039          0.6             0.9         1.2          0.1       15.1
# 3139  56041          0.7             1.3         0.6          0.2        9.0
# 3140  56043          0.5             1.7         0.8          0.1       13.9
# 3141  56045          0.6             1.5         0.6          0.0        4.0
#
#       perc_nonhisp_white
# 0                   75.0
# 1                   83.2
# 2                   46.5
# 3                   74.4
# 4                   87.5
# ...                  ...
# 3137                79.6
# 3138                81.5
# 3139                87.5
# 3140                82.6
# 3141                91.9
#
# [3142 rows x 7 columns]

# %%
sociohealth2 = pd.merge(sociohealth, races, how = 'left', on = 'FIPS')
sociohealth2
# Out:
#        FIPS    Pop_Dens  perc_below_pov  perc_disabled  perc_minority  \
# 0      1001   92.859967            15.4           19.3           25.0
# 1      1003  130.901947            10.6           14.0           17.0
# 2      1005   29.132150            28.9           22.2           53.9
# 3      1007   36.190214            14.0           16.7           25.4
# 4      1009   89.395591            14.4           14.2           12.9
# ...     ...         ...             ...            ...            ...
# 3137  56037    4.231045            12.0           12.3           20.4
# 3138  56039    5.769301             7.1            7.0           18.4
# 3139  56041    9.899987            12.5           17.2           12.5
# 3140  56043    3.631169            12.4           14.9           18.0
# 3141  56045    2.960796            17.4           14.4            8.9
#
#       percent_multiunit_housing  perc_overcrowded  perc_no_vehicle  \
# 0                           3.8               1.4              5.6
# 1                          18.3               1.3              3.4
# 2                           1.3               3.4              9.2
# 3                           2.4               0.8              6.0
# 4                           0.9               1.6              4.2
# ...                         ...               ...              ...
# 3137                        5.5               1.9              2.4
# 3138                        7.5               7.2              2.4
# 3139                        5.8               2.8              3.9
# 3140                        1.1               1.8              5.0
# 3141                        2.6               2.3              2.6
#
#       perc_group_quarters  perc_fair_poor_health  ...  uninsured  lim_eng  \
# 0                     1.0                     18  ...       8.05     0.80
# 1                     1.4                     18  ...      11.10     0.65
# 2                    11.2                     26  ...      12.10     1.55
# 3                     9.3                     20  ...       9.95     0.35
# 4                     0.9                     21  ...      12.50     1.80
# ...                   ...                    ...  ...        ...      ...
# 3137                  1.3                     15  ...      12.00     1.85
# 3138                  4.0                     12  ...      12.50     3.95
# 3139                  1.3                     16  ...      12.10     1.00
# 3140                  2.0                     16  ...      16.20     0.50
# 3141                  5.1                     13  ...      13.65     1.00
#
#        per_dem   per_gop  perc_afr_am  perc_nat_am_as  perc_asian  \
# 0     0.239569  0.734358         19.0             0.5         1.1
# 1     0.195653  0.773515          9.0             0.8         1.1
# 2     0.466603  0.522714         47.5             0.6         0.5
# 3     0.214220  0.769662         21.6             0.4         0.2
# 4     0.084699  0.898519          1.4             0.6         0.3
# ...        ...       ...          ...             ...         ...
# 3137  0.194046  0.729428          1.1             1.5         0.8
# 3138  0.600608  0.321945          0.6             0.9         1.2
# 3139  0.149261  0.764187          0.7             1.3         0.6
# 3140  0.143203  0.783580          0.5             1.7         0.8
# 3141  0.088182  0.869226          0.6             1.5         0.6
#
#       perc_nh_opi  perc_hisp  perc_nonhisp_white
# 0             0.1        2.7                75.0
# 1             0.1        4.4                83.2
# 2             0.2        4.2                46.5
# 3             0.1        2.5                74.4
# 4             0.1        9.1                87.5
# ...           ...        ...                 ...
# 3137          0.2       16.1                79.6
# 3138          0.1       15.1                81.5
# 3139          0.2        9.0                87.5
# 3140          0.1       13.9                82.6
# 3141          0.0        4.0                91.9
#
# [3142 rows x 38 columns]

# %%
sociohealth2.to_csv('data/sociohealth2.csv', index = False)

# %%
X = state_orders[['order_length','days_since_order', 'days_since_reopen', 'ann_to_eff']]

# %%
X = state_orders[['order_length','days_since_order', 'days_since_reopen']]

# %%
X = pd.merge(state_orders, sociohealth, how = 'left', on = 'FIPS')

# %%
X = pd.merge(state_orders, sociohealth2, how = 'left', on = 'FIPS')

# %%
X
# Out:
#        FIPS    STATE date_announced date_effective   date_lift date_reopen  \
# 0      1001  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# 1      1003  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# 2      1005  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# 3      1007  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# 4      1009  ALABAMA     2020-04-03     2020-04-04  2020-04-30  2020-04-30
# ...     ...      ...            ...            ...         ...         ...
# 3137  56037  WYOMING     2020-05-14     2020-05-14  2020-05-14  2020-05-01
# 3138  56039  WYOMING     2020-05-14     2020-05-14  2020-05-14  2020-05-01
# 3139  56041  WYOMING     2020-05-14     2020-05-14  2020-05-14  2020-05-01
# 3140  56043  WYOMING     2020-05-14     2020-05-14  2020-05-14  2020-05-01
# 3141  56045  WYOMING     2020-05-14     2020-05-14  2020-05-14  2020-05-01
#
#       order_length  days_since_order  days_since_reopen  ann_to_eff  ...  \
# 0               26                40                 14           1  ...
# 1               26                40                 14           1  ...
# 2               26                40                 14           1  ...
# 3               26                40                 14           1  ...
# 4               26                40                 14           1  ...
# ...            ...               ...                ...         ...  ...
# 3137             0                 0                 13           0  ...
# 3138             0                 0                 13           0  ...
# 3139             0                 0                 13           0  ...
# 3140             0                 0                 13           0  ...
# 3141             0                 0                 13           0  ...
#
#       uninsured  lim_eng   per_dem   per_gop  perc_afr_am  perc_nat_am_as  \
# 0          8.05     0.80  0.239569  0.734358         19.0             0.5
# 1         11.10     0.65  0.195653  0.773515          9.0             0.8
# 2         12.10     1.55  0.466603  0.522714         47.5             0.6
# 3          9.95     0.35  0.214220  0.769662         21.6             0.4
# 4         12.50     1.80  0.084699  0.898519          1.4             0.6
# ...         ...      ...       ...       ...          ...             ...
# 3137      12.00     1.85  0.194046  0.729428          1.1             1.5
# 3138      12.50     3.95  0.600608  0.321945          0.6             0.9
# 3139      12.10     1.00  0.149261  0.764187          0.7             1.3
# 3140      16.20     0.50  0.143203  0.783580          0.5             1.7
# 3141      13.65     1.00  0.088182  0.869226          0.6             1.5
#
#       perc_asian  perc_nh_opi  perc_hisp  perc_nonhisp_white
# 0            1.1          0.1        2.7                75.0
# 1            1.1          0.1        4.4                83.2
# 2            0.5          0.2        4.2                46.5
# 3            0.2          0.1        2.5                74.4
# 4            0.3          0.1        9.1                87.5
# ...          ...          ...        ...                 ...
# 3137         0.8          0.2       16.1                79.6
# 3138         1.2          0.1       15.1                81.5
# 3139         0.6          0.2        9.0                87.5
# 3140         0.8          0.1       13.9                82.6
# 3141         0.6          0.0        4.0                91.9
#
# [3142 rows x 50 columns]

# %%
X.drop(columns = ['FIPS', 'STATE','date_announced','date_effective','date_lift','date_reopen'], inplace = True)

# %%
#X.drop(columns = ['ann_to_eff', 'perc_diab','17_younger'], inplace = True)

# %%
#X.drop(columns = ['unemployed'], inplace = True)

# %%
#X.drop(columns = ['perc_disabled', 'pcp_rate_100k', 'perc_group_quarters', ], inplace = True)

# %%
X
# Out:
#       order_length  days_since_order  days_since_reopen  ann_to_eff  reopened  \
# 0               26                40                 14           1         1
# 1               26                40                 14           1         1
# 2               26                40                 14           1         1
# 3               26                40                 14           1         1
# 4               26                40                 14           1         1
# ...            ...               ...                ...         ...       ...
# 3137             0                 0                 13           0         1
# 3138             0                 0                 13           0         1
# 3139             0                 0                 13           0         1
# 3140             0                 0                 13           0         1
# 3141             0                 0                 13           0         1
#
#       days_since_lifted  lifted    Pop_Dens  perc_below_pov  perc_disabled  \
# 0                    14       1   92.859967            15.4           19.3
# 1                    14       1  130.901947            10.6           14.0
# 2                    14       1   29.132150            28.9           22.2
# 3                    14       1   36.190214            14.0           16.7
# 4                    14       1   89.395591            14.4           14.2
# ...                 ...     ...         ...             ...            ...
# 3137                  0       1    4.231045            12.0           12.3
# 3138                  0       1    5.769301             7.1            7.0
# 3139                  0       1    9.899987            12.5           17.2
# 3140                  0       1    3.631169            12.4           14.9
# 3141                  0       1    2.960796            17.4           14.4
#
#       ...  uninsured  lim_eng   per_dem   per_gop  perc_afr_am  \
# 0     ...       8.05     0.80  0.239569  0.734358         19.0
# 1     ...      11.10     0.65  0.195653  0.773515          9.0
# 2     ...      12.10     1.55  0.466603  0.522714         47.5
# 3     ...       9.95     0.35  0.214220  0.769662         21.6
# 4     ...      12.50     1.80  0.084699  0.898519          1.4
# ...   ...        ...      ...       ...       ...          ...
# 3137  ...      12.00     1.85  0.194046  0.729428          1.1
# 3138  ...      12.50     3.95  0.600608  0.321945          0.6
# 3139  ...      12.10     1.00  0.149261  0.764187          0.7
# 3140  ...      16.20     0.50  0.143203  0.783580          0.5
# 3141  ...      13.65     1.00  0.088182  0.869226          0.6
#
#       perc_nat_am_as  perc_asian  perc_nh_opi  perc_hisp  perc_nonhisp_white
# 0                0.5         1.1          0.1        2.7                75.0
# 1                0.8         1.1          0.1        4.4                83.2
# 2                0.6         0.5          0.2        4.2                46.5
# 3                0.4         0.2          0.1        2.5                74.4
# 4                0.6         0.3          0.1        9.1                87.5
# ...              ...         ...          ...        ...                 ...
# 3137             1.5         0.8          0.2       16.1                79.6
# 3138             0.9         1.2          0.1       15.1                81.5
# 3139             1.3         0.6          0.2        9.0                87.5
# 3140             1.7         0.8          0.1       13.9                82.6
# 3141             1.5         0.6          0.0        4.0                91.9
#
# [3142 rows x 44 columns]

# %%
X.columns
# Out:
# Index(['order_length', 'days_since_order', 'days_since_reopen', 'ann_to_eff',
#        'reopened', 'days_since_lifted', 'lifted', 'Pop_Dens', 'perc_below_pov',
#        'perc_disabled', 'perc_minority', 'percent_multiunit_housing',
#        'perc_overcrowded', 'perc_no_vehicle', 'perc_group_quarters',
#        'perc_fair_poor_health', 'perc_smokers', 'perc_obese',
#        'perc_phys_inactive', 'prev_hosp_rate_medicare', 'air_pollution',
#        'unemployed', 'age_adjusted_mortality', 'perc_diab', 'perc_insuf_sleep',
#        'health_costs', 'med_house_income', 'wnw_seg', 'Population', 'perc_fem',
#        'perc_rural', 'pcp_rate_100k', '65_older', '17_younger', 'uninsured',
#        'lim_eng', 'per_dem', 'per_gop', 'perc_afr_am', 'perc_nat_am_as',
#        'perc_asian', 'perc_nh_opi', 'perc_hisp', 'perc_nonhisp_white'],
#       dtype='object')

# %%
y = (metadata_byday.iloc[:,-1] > metadata_byday.iloc[:,-5]).astype(int)

# %%
y.value_counts()
# Out:
# 0    1892
# 1    1250
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
rfc = RandomForestClassifier(oob_score = True)
rfc.fit(X_train, y_train)

rfc.score(X_test, y_test)
# Out:
# 0.7557251908396947

# %%
feature_scores = pd.Series(rfc.feature_importances_, index=X.columns)
feature_scores = feature_scores.sort_values()

ax = feature_scores.plot(kind='barh', figsize=(10,10))
ax.set_title('Average Gini Importance')
ax.set_xlabel('Average contribution of information gain')
# Out:
# Text(0.5, 0, 'Average contribution of information gain')

# %%
imp = importances(rfc, X_test, y_test, n_samples=-1)
viz = plot_importances(imp)
viz.view()

# %%
#rf1 = rfc.fit(X_train1, y_train1)
confusion_matrix(y_test, rfc.predict(X_test))
# Out:
# array([[401,  81],
#        [114, 190]])

# %%
precision_score(y_test, rfc.predict(X_test))
# Out:
# 0.7011070110701108

# %%
recall_score(y_test, rfc.predict(X_test))
# Out:
# 0.625

# %%
#on just statewide orders
65, 60, 51
69, 63, 52
68, 60, 64
# Out:
# (68, 60, 64)

# %%
#added in all sociohealth features
77, 73, 64
77, 72, 67
75, 72, 62
76, 73, 65
77, 76, 64
78, 75, 66
# Out:
# (78, 75, 66)

# %%
#dropped a few sociohealth
79, 78, 70
78, 77, 68
78, 76, 68
78, 76, 66
78, 76, 65
78, 75, 65
# Out:
# (78, 75, 65)

# %%
estimator_list = [50, 75, 100, 125, 150]
score_list = []
for i in estimator_list:
    rfc = RandomForestClassifier(n_estimators=i, oob_score=True)
    rfc.fit(X_train, y_train)
    score_list.append(rfc.score(X_test, y_test))
estimator_scores = dict(zip(estimator_list, score_list))
estimator_scores
# Out:
# {50: 0.7417302798982188,
#  75: 0.7582697201017812,
#  100: 0.7569974554707379,
#  125: 0.7608142493638677,
#  150: 0.7595419847328244}

# %%
x = estimator_list
y = score_list
fig, ax = plt.subplots()
ax.plot(x,y)

# %%
max_features = []
score_list = []
for i in range(1, len(X.columns)):
    rfc = RandomForestClassifier(max_features=i, oob_score=True)
    rfc.fit(X_train, y_train)
    score_list.append(rfc.score(X_test, y_test))
    max_features.append(i)
feature_scores = dict(zip(max_features, score_list))

# %%
feature_scores
# Out:
# {1: 0.7582697201017812,
#  2: 0.7646310432569975,
#  3: 0.7595419847328244,
#  4: 0.7659033078880407,
#  5: 0.7569974554707379,
#  6: 0.7468193384223919,
#  7: 0.772264631043257,
#  8: 0.7557251908396947,
#  9: 0.7595419847328244,
#  10: 0.7544529262086515,
#  11: 0.7557251908396947,
#  12: 0.7531806615776081,
#  13: 0.7595419847328244,
#  14: 0.7506361323155216,
#  15: 0.7506361323155216,
#  16: 0.7646310432569975,
#  17: 0.7620865139949109,
#  18: 0.7620865139949109,
#  19: 0.7709923664122137,
#  20: 0.7582697201017812,
#  21: 0.7760814249363868,
#  22: 0.7506361323155216,
#  23: 0.767175572519084,
#  24: 0.7569974554707379,
#  25: 0.7493638676844784,
#  26: 0.7620865139949109,
#  27: 0.7633587786259542,
#  28: 0.767175572519084,
#  29: 0.7633587786259542,
#  30: 0.767175572519084,
#  31: 0.7659033078880407,
#  32: 0.7608142493638677,
#  33: 0.7684478371501272,
#  34: 0.7569974554707379,
#  35: 0.7557251908396947,
#  36: 0.772264631043257,
#  37: 0.772264631043257,
#  38: 0.7531806615776081,
#  39: 0.7595419847328244,
#  40: 0.7633587786259542,
#  41: 0.7544529262086515,
#  42: 0.7608142493638677,
#  43: 0.7633587786259542}

# %%
x = max_features
y = score_list
fig, ax = plt.subplots()
ax.plot(x,y)
